# %% [markdown]
# # MERCURY Entity Interrogator
#
# This notebook guides you through two distinct stages:
# 1. **Stage 1: Select Cached Dataset Pair** — Choose which pre-indexed cache pair to load into memory.
# 2. **Stage 2: Querying & Entity Diagnostics** — Interactively query entity mentions across languages, analyze co-occurring entities, and inspect cluster quality diagnostics.

# %% [markdown]
# ## Stage 1: Select Cached Dataset Pair
# Select a registered dataset/cache pair and load its vectors and metadata into memory.

# %%
from MERCURY import MERCURY

engine = MERCURY()
engine.get_pair_selection_notebook_ui()

# %% [markdown]
# ## Stage 2: Entity Interrogation & Diagnostics
# Perform search queries, select cross-encoder models for Stage 2 re-ranking, and inspect cluster quality diagnostics.

# %%
engine.get_notebook_ui()
