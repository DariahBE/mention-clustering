# %% [markdown]
# # MERCURY Index Generator
#
# This notebook guides you through two distinct stages:
# 1. **Stage 1: Dataset Inspection & Schema Mapping** — Auto-detects delimiters (CSV vs TSV) and maps raw column names to MERCURY's internal schema.
# 2. **Stage 2: Vector Encoding, Index Generation & Clustering** — Selects vector models, generates dual-encoder embeddings, builds FAISS indexes, and clusters entity mentions.

# %% [markdown]
# ## Stage 1: Dataset Inspection & Schema Mapping
# Select a dataset file (e.g. `data/prepared_data.tsv` or `data/dataset.csv`) to inspect raw columns and verify auto-detected schema mappings.

# %%
from MERCURY import MERCURY

engine = MERCURY()
engine.get_mapping_notebook_ui()

# %% [markdown]
# ## Stage 2: Vector Encoding, Index Generation & Clustering
# Select your dataset/cache pair, target transformer vector model, and clustering algorithm to generate vector indexes and medoid clusters.

# %%
engine.get_generator_notebook_ui()
